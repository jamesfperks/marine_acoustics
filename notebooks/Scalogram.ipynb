# %%
import os
from marine_acoustics.utils import call_selector
from marine_acoustics.visualisation import scalogram

# Remove later....
import pywt
import numpy as np
import matplotlib.pyplot as plt
from marine_acoustics.configuration import settings as s

# Change cwd
os.chdir(r'C:\Users\james\OneDrive - Nexus365\Engineering\Year4\4YP\git\marine_acoustics')

# Figures appear in notebook inline
# %matplotlib inline

# %% [markdown]
# ### Plot the wavelet scaleogram of a specific call

# %%
# ---------------------------
SITE = 9
# ---------------------------
CALL_TYPE = 3
# ---------------------------
WAVFILE = '20150403_090000'
# ---------------------------
TIME = '2015/4/3  9:39:09.114'      # Note the date time has TWO spaces between
# ---------------------------
PADDING = 5                         # Number of seconds to pad both sides of call selection
# ---------------------------

# Plot wavelet
y = call_selector.get_call_audio(SITE, CALL_TYPE, WAVFILE, TIME, PADDING)
scalogram.plot_scalogram(y, wavelet='cmor45-1.6')
