# %% [markdown]
# ### Find annotations for given site and call types

# %%
import os
from marine_acoustics.utils import call_selector

# Change cwd
os.chdir(r'C:\Users\james\OneDrive - Nexus365\Engineering\Year4\4YP\git\marine_acoustics')

# %%
# ---------------------------
SITE = 9
# ---------------------------
CALLS = [1,2,3]                    # E.g. [1,2,3] to show A,B,Z calls
# ---------------------------

gb_wavfile = call_selector.get_call_annotations(SITE, CALLS)
for wav, logs in gb_wavfile:
        display(logs)
# Out:
# Balleny Islands 2015
#  ['Bm-A', 'Bm-B', 'Bm-Z']
#             Begin File  Begin (s)  ...  Freq 5% (Hz) Freq 95% (Hz)
# 0  20150204_030000.wav     1652.0  ...          23.4          27.3
#
# [1 rows x 11 columns]
#             Begin File  Begin (s)  ...  Freq 5% (Hz) Freq 95% (Hz)
# 3  20150216_110000.wav     3047.2  ...          24.4          27.3
# 2  20150216_110000.wav     3144.7  ...          25.4          26.4
# 1  20150216_110000.wav     3250.4  ...          22.5          26.4
#
# [3 rows x 11 columns]
#              Begin File  Begin (s)  ...  Freq 5% (Hz) Freq 95% (Hz)
# 21  20150220_000000.wav       31.2  ...          23.4          26.4
# 20  20150220_000000.wav       69.0  ...          25.4          27.3
# 12  20150220_000000.wav       98.1  ...          23.4          27.3
# 5   20150220_000000.wav      150.0  ...          24.4          26.4
# 13  20150220_000000.wav      163.2  ...          23.4          27.3
# ...

# %% [markdown]
# ### Show calls in a specific .wav file

# %%
display(gb_wavfile.get_group('20150501_140000.wav').tail(5))
# Out:
#               Begin File  Begin (s)  ...  Freq 5% (Hz) Freq 95% (Hz)
# 803  20150501_140000.wav     3306.9  ...          23.4          26.4
# 802  20150501_140000.wav     3374.6  ...          24.4          27.3
# 768  20150501_140000.wav     3442.7  ...          24.4          26.4
# 776  20150501_140000.wav     3508.6  ...          24.4          27.3
# 796  20150501_140000.wav     3573.6  ...          23.4          28.3
#
# [5 rows x 11 columns]
