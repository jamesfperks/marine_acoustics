# %%
import os
from marine_acoustics.utils import call_selector
from marine_acoustics.visualisation import spectrogram

# Change cwd
os.chdir(r'C:\Users\james\OneDrive - Nexus365\Engineering\Year4\4YP\git\marine_acoustics')

# Figures appear in notebook inline
# %matplotlib inline

# %% [markdown]
# ### Plot the power spectrogram of a specific call

# %%
# ---------------------------
SITE = 9
# ---------------------------
CALL_TYPE = 3
# ---------------------------
WAVFILE = '20150403_090000'
# ---------------------------
TIME = '2015/2/16  11:54:10.436'      # Note the date time has TWO spaces between
# ---------------------------
PADDING = 11                         # Number of seconds to pad both sides of call selection
# ---------------------------
  
y = call_selector.get_call_audio(SITE, CALL_TYPE, WAVFILE, TIME, PADDING)
spectrogram.plot_spectrogram(y)
